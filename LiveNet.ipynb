# %% [markdown]
# **connect to google driver**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **import project folder in colab**

# %%
from zipfile import ZipFile
file_name='/content/drive/MyDrive/mlprojecta.zip'
with ZipFile(file_name ,'r') as zip :
  zip.extractall()
  print('finish')
# Out:
# finish

# %% [markdown]
# **creat real face images by following command**

# %%
# !python /content/mlproject/vrmlpro/gather_examples.py --input /content/mlproject/vrmlpro/videos/real.mp4 --output /content/mlproject/vrmlpro/dataset/real \
	--detector /content/mlproject/vrmlpro/face_detector --skip 1
# Out:
# [INFO] loading face detector...
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/0.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/1.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/2.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/3.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/4.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/5.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/6.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/7.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/8.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/9.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/10.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/11.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/real/12.png to disk
# ...

# %% [markdown]
# **creat fake face images by following command**

# %%
# !python /content/mlproject/vrmlpro/gather_examples.py --input /content/mlproject/vrmlpro/videos/fake.mp4 --output /content/mlproject/vrmlpro/dataset/fake \
	--detector /content/mlproject/vrmlpro/face_detector --skip 1
# Out:
# [INFO] loading face detector...
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/0.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/1.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/2.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/3.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/4.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/5.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/6.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/7.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/8.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/9.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/10.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/11.png to disk
# [INFO] saved /content/mlproject/vrmlpro/dataset/fake/12.png to disk
# ...

# %% [markdown]
# **know we train model and plot train accuracy and loss**

# %%
# !python /content/mlprojecta/vrmlpro/train.py --dataset /content/mlprojecta/vrmlpro/dataset --model /content/mlprojecta/vrmlpro/liveness.model --le /content/mlprojecta/vrmlpro/le.pickle  --plot /content/mlprojecta/vrmlpro/plot.png
# Out:
# [INFO] loading images...
# [INFO] compiling model...
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# 2021-10-30 20:43:42.405147: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2021-10-30 20:43:42.405216: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (79b6fd813eda): /proc/driver/nvidia/version does not exist
# [INFO] training network for 50 epochs...
# 2021-10-30 20:43:43.114761: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/50
# 135/135 [==============================] - 7s 41ms/step - loss: 0.3564 - accuracy: 0.8748 - val_loss: 0.6091 - val_accuracy: 0.9945
# ...

# %% [markdown]
# **here we loading face detector and liveness detector**
#
# **than after start video stream**
#
# **by following cmd line**
#
# **Note-here we can't open camera for video stream so we use cmd promp**t

# %%
# !python  /content/mlprojecta/vrmlpro/liveness_demo.py --model /content/mlprojecta/vrmlpro/liveness.model --le /content/mlprojecta/vrmlpro/le.pickle  \
	--detector /content/mlprojecta/vrmlpro/face_detector
# Out:
# [INFO] loading face detector...
# [INFO] loading liveness detector...
# 2021-10-30 18:53:04.958474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-30 18:53:04.967027: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-30 18:53:04.967792: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-10-30 18:53:04.969238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...
